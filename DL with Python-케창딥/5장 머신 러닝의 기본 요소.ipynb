# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import imdb
import numpy as np
(train_data, train_label), (test_data, test_label) = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1.
  return results
train_data = vectorize_sequences(train_data)

model = keras.Sequential([
    layers.Dense(16, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history_original = model.fit(
    train_data, train_label,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# Epoch 1/20
# 30/30 [==============================] - 7s 66ms/step - loss: 0.5473 - accuracy: 0.7603 - val_loss: 0.4038 - val_accuracy: 0.8658
# Epoch 2/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.3317 - accuracy: 0.8903 - val_loss: 0.3156 - val_accuracy: 0.8841
# Epoch 3/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.2467 - accuracy: 0.9181 - val_loss: 0.3139 - val_accuracy: 0.8727
# Epoch 4/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1990 - accuracy: 0.9327 - val_loss: 0.2984 - val_accuracy: 0.8793
# Epoch 5/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.1661 - accuracy: 0.9451 - val_loss: 0.2762 - val_accuracy: 0.8904
# Epoch 6/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1393 - accuracy: 0.9548 - val_loss: 0.2966 - val_accuracy: 0.8827
# Epoch 7/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1219 - accuracy: 0.9615 - val_loss: 0.2941 - val_accuracy: 0.8852
# Epoch 8/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1024 - accuracy: 0.9696 - val_loss: 0.3082 - val_accuracy: 0.8852
# Epoch 9/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0881 - accuracy: 0.9747 - val_loss: 0.3424 - val_accuracy: 0.8760
# Epoch 10/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0788 - accuracy: 0.9780 - val_loss: 0.3621 - val_accuracy: 0.8745
# Epoch 11/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0621 - accuracy: 0.9853 - val_loss: 0.3612 - val_accuracy: 0.8806
# Epoch 12/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0549 - accuracy: 0.9878 - val_loss: 0.3904 - val_accuracy: 0.8748
# Epoch 13/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0476 - accuracy: 0.9893 - val_loss: 0.4001 - val_accuracy: 0.8769
# Epoch 14/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0384 - accuracy: 0.9925 - val_loss: 0.4255 - val_accuracy: 0.8761
# Epoch 15/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0342 - accuracy: 0.9923 - val_loss: 0.4484 - val_accuracy: 0.8733
# Epoch 16/20
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0299 - accuracy: 0.9939 - val_loss: 0.4711 - val_accuracy: 0.8728
# Epoch 17/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0248 - accuracy: 0.9957 - val_loss: 0.4914 - val_accuracy: 0.8732
# Epoch 18/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0174 - accuracy: 0.9976 - val_loss: 0.5130 - val_accuracy: 0.8712
# Epoch 19/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0197 - accuracy: 0.9954 - val_loss: 0.5380 - val_accuracy: 0.8708
# Epoch 20/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0112 - accuracy: 0.9989 - val_loss: 0.5623 - val_accuracy: 0.8702

# %% [markdown]
# ㅇㄹㄴㅁㄹㄴㅁㄹㄴ[링크 텍스트](https://)
